# %% [markdown]
# <a href="https://colab.research.google.com/github/MilizCom/Neural-Network/blob/main/Generatif_AI%2C_Auto_Answear_Comment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import json

# Ganti dengan API key kamu yang baru dan aman
api_key = "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"

def generate_reply_manual(comment):
    headers = {
        "Authorization": f"Bearer {api_key}",
        "Content-Type": "application/json"
    }

    body = {
        "model": "openai/gpt-3.5-turbo",
        "messages": [
            {"role": "user", "content": f"Balas komentar negatif ini dengan sopan dan profesional:\nKomentar: \"{comment}\"\nBalasan:"}
        ]
    }

    response = requests.post("https://openrouter.ai/api/v1/chat/completions", headers=headers, data=json.dumps(body))

    if response.status_code == 200:
        return response.json()['choices'][0]['message']['content']
    else:
        return f"Error: {response.status_code}, {response.text}"

# Tes
komentar = "Makanan di Toko ini dingin semua"
balasan = generate_reply_manual(komentar)
print("Komentar:", komentar)
print("Balasan:", balasan)
# Out:
# Komentar: Makanan di Toko ini dingin semua
# Balasan: Kami mohon maaf atas pengalaman yang kurang menyenangkan itu. Kami akan segera memberikan masukan ini kepada tim dapur kami untuk memastikan kualitas makanan kami tetap terjaga. Terima kasih atas tanggapannya.

# %%
d
